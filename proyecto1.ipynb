# %% [markdown]
# # Proyecto 1

# %% [markdown]
# ## 1. Crear un entorno de anaconda con los paquetes que considere necesarios.

# %%
# !git clone https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
# Out:
# Cloning into 'Proyecto-1---Regresi-n-con-Progra-'...

# %%
# !git add .
# Out:
# ...
# The file will have its original line endings in your working directory

# %%
# !git commit -m "Primer commit para comprobar que este funcionando GIT"
# Out:
# [main cd27100] Primer commit para comprobar que este funcionando GIT
#  1 file changed, 55 insertions(+)
#  create mode 100644 proyecto1.ipynb

# %%
# !git push
# Out:
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    41a99b5..cd27100  main -> main

# %%
# !git add .
# !git commit -m "Segundo commit para que se vaya grabando el avance"
# !git push
# Out:
# [main 6192888] Segundo commit para que se vaya grabando el avance
#  1 file changed, 69 insertions(+), 2 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    cd27100..6192888  main -> main

# %% [markdown]
# ## Iniciando la carga de datos

# %%
import numpy as np

datos = np.load('./proyecto_data/proyecto_training_data.npy')
datos
# Out:
# array([[2.08500e+05, 7.00000e+00, 8.56000e+02, 8.00000e+00, 2.00300e+03,
#         6.50000e+01],
#        [1.81500e+05, 6.00000e+00, 1.26200e+03, 6.00000e+00, 1.97600e+03,
#         8.00000e+01],
#        [2.23500e+05, 7.00000e+00, 9.20000e+02, 6.00000e+00, 2.00100e+03,
#         6.80000e+01],
#        ...,
#        [2.66500e+05, 7.00000e+00, 1.18800e+03, 9.00000e+00, 1.94100e+03,
#         6.60000e+01],
#        [1.42125e+05, 5.00000e+00, 1.07800e+03, 5.00000e+00, 1.95000e+03,
#         6.80000e+01],
#        [1.47500e+05, 5.00000e+00, 1.25600e+03, 6.00000e+00, 1.96500e+03,
#         7.50000e+01]])

# %%
# !git add .
# !git commit "Directorio de datos creado y datos cargados"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory
# error: pathspec 'Directorio de datos creado y datos cargados' did not match any file(s) known to git
# Everything up-to-date

# %%
# !git add .

# %%
# !git commit -m "La prueba anteriro de subir el directorio fallo este es otro intento"
# Out:
# [main 89e96dd] La prueba anteriro de subir el directorio fallo este es otro intento
#  4 files changed, 103 insertions(+), 1 deletion(-)
#  create mode 100644 proyecto_data/Data fields.txt
#  create mode 100644 proyecto_data/__MACOSX/._Data fields.txt
#  create mode 100644 proyecto_data/proyecto_training_data.npy

# %%
# !git push
# Out:
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    6192888..89e96dd  main -> main

# %% [markdown]
# ## A continuaci´on se le listan los pasos que deber´ıa seguir para poder desarrollar su proyecto:

# %% [markdown]
# 1. Crear un entorno de anaconda con los paquetes que considere necesarios.

# %% [markdown]
# En este caso utilize un entorno virual de python con venv para tener todas las bibliotecas disponibles sin que afecten a otros proyectos
#
#
# !python -m venv "../../.lab"
#
# esta en dos directorios anteriores porque tambien estoy usando ese entorno para las clases y las tareas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !git add .
# !git commit -m "Documentacion de los primeros pasos"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main fcf2fab] Documentacion de los primeros pasos
#  1 file changed, 109 insertions(+), 3 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    89e96dd..fcf2fab  main -> main

# %% [markdown]
# ### Exploracion de datos

# %%
datos
# Out:
# array([[2.08500e+05, 7.00000e+00, 8.56000e+02, 8.00000e+00, 2.00300e+03,
#         6.50000e+01],
#        [1.81500e+05, 6.00000e+00, 1.26200e+03, 6.00000e+00, 1.97600e+03,
#         8.00000e+01],
#        [2.23500e+05, 7.00000e+00, 9.20000e+02, 6.00000e+00, 2.00100e+03,
#         6.80000e+01],
#        ...,
#        [2.66500e+05, 7.00000e+00, 1.18800e+03, 9.00000e+00, 1.94100e+03,
#         6.60000e+01],
#        [1.42125e+05, 5.00000e+00, 1.07800e+03, 5.00000e+00, 1.95000e+03,
#         6.80000e+01],
#        [1.47500e+05, 5.00000e+00, 1.25600e+03, 6.00000e+00, 1.96500e+03,
#         7.50000e+01]])

# %%
datos.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 datos.shape()
#
# TypeError: 'tuple' object is not callable

# %%
np.shape(datos)
# Out:
# (1460, 6)

# %% [markdown]
# De lo anterior se puede ver que es un arreglo que contiene 6 columnas y 1460 filas

# %% [markdown]
# Cual el la columna se debe usar como Y?

# %%
import pandas as pd

# %%
type(datos)
# Out:
# numpy.ndarray

# %% [markdown]
# Data fields.txt
# Data fields
# Here's a brief version of what you'll find in the data description file.
#
# SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
#
#
# OverallQual: Overall material and finish quality, rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
#
# 1stFlrSF: First Floor square feet
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# YearBuilt: Original construction date
# LotFrontage: Linear feet of street connected to property

# %% [markdown]
# #### Las respectivas columnas son las siguientes (estraidas del archivo Data fields.txt)
# SalePrice
# OverallQual
# 1stFlrSF
# TotRmsAbvGrd
# YearBuilt
# LotFrontage

# %% [markdown]
# ##### Experimentanto convertir los datos de nupy en un DataFrame de pandas para que sean mas comprensibles

# %%
pd.DataFrame(datos,columns=[
'SalePrice', 
'OverallQual',
'1stFlrSF',
'TotRmsAbvGrd',
'YearBuilt',
'LotFrontage'])
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 0      208500.0          7.0     856.0           8.0     2003.0         65.0
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
# [1460 rows x 6 columns]

# %%
# !git add .
# !git commit -m "leyendo los datos con nupy y obteniendo un dataframe de pandas para que los datos sean mas entendibles"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 8d4af08] leyendo los datos con nupy y obteniendo un dataframe de pandas para que los datos sean mas entendibles
#  1 file changed, 388 insertions(+)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    fcf2fab..8d4af08  main -> main

# %% [markdown]
# 2. Usando sclicing con NumPy separar los datos en 2 datasets: entrenamiento(80 %) y validaci´on
# y pruebas(20 %).

# %%
data = pd.DataFrame(datos,columns=[
'SalePrice', 
'OverallQual',
'1stFlrSF',
'TotRmsAbvGrd',
'YearBuilt',
'LotFrontage'])

# %%
len(data)
# Out:
# 1460

# %%
entrenamiento = data[0:int(len(data)*0.8)]

entrenamiento
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 0      208500.0          7.0     856.0           8.0     2003.0         65.0
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# ...         ...          ...       ...           ...        ...          ...
# 1163   108959.0          4.0    1258.0           6.0     1969.0         60.0
# 1164   194000.0          5.0    1432.0           5.0     1978.0          NaN
# 1165   233170.0          7.0    1502.0           7.0     2009.0         79.0
# 1166   245350.0          8.0    1694.0           7.0     2008.0         64.0
# 1167   173000.0          6.0     959.0           7.0     2000.0         58.0
#
# [1168 rows x 6 columns]

# %%
validacion= data[int(len(data)*0.8):]
validacion
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 1168   235000.0          6.0    1236.0           7.0     1935.0        120.0
# 1169   625000.0         10.0    1831.0          10.0     1995.0        118.0
# 1170   171000.0          6.0    1118.0           6.0     1977.0         76.0
# 1171   163000.0          6.0    1261.0           6.0     1958.0         76.0
# 1172   171900.0          7.0     625.0           5.0     2006.0         35.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
# [292 rows x 6 columns]

# %%
len(data)-len(entrenamiento)-len(validacion)
# Out:
# 0

# %%
# !git add .
# !git commit -m "separacion de datos"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 84dbd54] separacion de datos
#  1 file changed, 434 insertions(+), 1 deletion(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    8d4af08..84dbd54  main -> main

# %%
def separacionData(data,segmentacion = 0.8):
    entrenamiento = data[0:int(len(data)*segmentacion)]
    validacion= data[int(len(data)*segmentacion):]
    return entrenamiento,validacion

ent,val = separacionData(data,0.8)

# %%
ent
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 0      208500.0          7.0     856.0           8.0     2003.0         65.0
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# ...         ...          ...       ...           ...        ...          ...
# 1163   108959.0          4.0    1258.0           6.0     1969.0         60.0
# 1164   194000.0          5.0    1432.0           5.0     1978.0          NaN
# 1165   233170.0          7.0    1502.0           7.0     2009.0         79.0
# 1166   245350.0          8.0    1694.0           7.0     2008.0         64.0
# 1167   173000.0          6.0     959.0           7.0     2000.0         58.0
#
# [1168 rows x 6 columns]

# %%
val
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 1168   235000.0          6.0    1236.0           7.0     1935.0        120.0
# 1169   625000.0         10.0    1831.0          10.0     1995.0        118.0
# 1170   171000.0          6.0    1118.0           6.0     1977.0         76.0
# 1171   163000.0          6.0    1261.0           6.0     1958.0         76.0
# 1172   171900.0          7.0     625.0           5.0     2006.0         35.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
# [292 rows x 6 columns]

# %%
datos = np.load('./proyecto_data/proyecto_training_data.npy')
data = pd.DataFrame(datos,columns=[
'SalePrice', 
'OverallQual',
'1stFlrSF',
'TotRmsAbvGrd',
'YearBuilt',
'LotFrontage'])

def npyToPandas(direccion):
    datos = np.load(direccion)
    return pd.DataFrame(datos,columns=[
    'SalePrice', 
    'OverallQual',
    '1stFlrSF',
    'TotRmsAbvGrd',
    'YearBuilt',
    'LotFrontage'])

# %% [markdown]
# ## 2. Usando sclicing con NumPy separar los datos en 2 datasets: entrenamiento(80 %) y validaci´on
# y pruebas(20 %).

# %%
import numpy as np
import pandas as pd

def npyToPandas(direccion):
    datos = np.load(direccion)
    return pd.DataFrame(datos,columns=[
    'SalePrice', 
    'OverallQual',
    '1stFlrSF',
    'TotRmsAbvGrd',
    'YearBuilt',
    'LotFrontage'])

def separacionData(data,segmentacion = 0.8):
    entrenamiento = data[0:int(len(data)*segmentacion)]
    validacion= data[int(len(data)*segmentacion):]
    return entrenamiento,validacion

data = npyToPandas('./proyecto_data/proyecto_training_data.npy')

ent,val = separacionData(data,0.8)

# %%
# !git add .
# !git commit -m "Funcion de leer datos y convertirlos a pandas y funcion de separar datos implementadas"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 0b3cd72] Funcion de leer datos y convertirlos a pandas y funcion de separar datos implementadas
#  1 file changed, 476 insertions(+), 1 deletion(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    84dbd54..0b3cd72  main -> main

# %% [markdown]
# 3. An´alisis exploratorio de datos: Para cada variable en el dataset calcular((usando numpy o
# pandas):
# media
# valor m´aximo
# valor m´ınimo
# rango(peak to peak, no el rango del tensor que por ser vector sabemos que es 1)
# desviaci´on est´andar.

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SalePrice     1460 non-null   float64
#  1   OverallQual   1460 non-null   float64
#  2   1stFlrSF      1460 non-null   float64
#  3   TotRmsAbvGrd  1460 non-null   float64
#  4   YearBuilt     1460 non-null   float64
#  5   LotFrontage   1201 non-null   float64
# dtypes: float64(6)
# memory usage: 68.6 KB

# %%
data.describe()
# Out:
#            SalePrice  OverallQual     1stFlrSF  TotRmsAbvGrd    YearBuilt  \
# count    1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   180921.195890     6.099315  1162.626712      6.517808  1971.267808
# std     79442.502883     1.382997   386.587738      1.625393    30.202904
# min     34900.000000     1.000000   334.000000      2.000000  1872.000000
# 25%    129975.000000     5.000000   882.000000      5.000000  1954.000000
# 50%    163000.000000     6.000000  1087.000000      6.000000  1973.000000
# 75%    214000.000000     7.000000  1391.250000      7.000000  2000.000000
# max    755000.000000    10.000000  4692.000000     14.000000  2010.000000
#
#        LotFrontage
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# 25%      59.000000
# 50%      69.000000
# 75%      80.000000
# max     313.000000

# %%
rango = data.max() - data.min()

# Convierte el rango en un DataFrame y transpónlo
rango_df = pd.DataFrame(rango).transpose()

# Concatena los DataFrames
resultado = pd.concat([data.describe(), rango_df]).rename(index={0: 'Rango'})
resultado
# Out:
#            SalePrice  OverallQual     1stFlrSF  TotRmsAbvGrd    YearBuilt  \
# count    1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   180921.195890     6.099315  1162.626712      6.517808  1971.267808
# std     79442.502883     1.382997   386.587738      1.625393    30.202904
# min     34900.000000     1.000000   334.000000      2.000000  1872.000000
# 25%    129975.000000     5.000000   882.000000      5.000000  1954.000000
# 50%    163000.000000     6.000000  1087.000000      6.000000  1973.000000
# 75%    214000.000000     7.000000  1391.250000      7.000000  2000.000000
# max    755000.000000    10.000000  4692.000000     14.000000  2010.000000
# Rango  720100.000000     9.000000  4358.000000     12.000000   138.000000
#
#        LotFrontage
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# 25%      59.000000
# 50%      69.000000
# 75%      80.000000
# max     313.000000
# Rango   292.000000

# %%
# !git add .
# !git commit -m "Estadisticas de cada columna"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 69645bd] Estadisticas de cada columna
#  1 file changed, 382 insertions(+), 1 deletion(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    0b3cd72..69645bd  main -> main

# %% [markdown]
# ## 3. An´alisis exploratorio de datos: Para cada variable en el dataset calcular((usando numpy o
# pandas):
# * media
# * valor m´aximo
# * valor m´ınimo
# * rango(peak to peak, no el rango del tensor que por ser vector sabemos que es 1)
# * desviaci´on est´andar.

# %%
resultado.loc[[
'count'	,
'mean'	,
'std'	,##desviacion standard
'min'	,
'max'	,
'Rango'	
],:]
# Out:
#            SalePrice  OverallQual     1stFlrSF  TotRmsAbvGrd    YearBuilt  \
# count    1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   180921.195890     6.099315  1162.626712      6.517808  1971.267808
# std     79442.502883     1.382997   386.587738      1.625393    30.202904
# min     34900.000000     1.000000   334.000000      2.000000  1872.000000
# max    755000.000000    10.000000  4692.000000     14.000000  2010.000000
# Rango  720100.000000     9.000000  4358.000000     12.000000   138.000000
#
#        LotFrontage
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# max     313.000000
# Rango   292.000000

# %%
# !git add .
# !git commit -m "Prueba de graficas anuladas"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 7195b3a] Prueba de graficas anuladas
#  1 file changed, 1 insertion(+), 1381 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    44670ab..7195b3a  main -> main

# %%
! pip install seaborn
# Out:
# ...
#      -------------------------------------- 293.3/293.3 KB 1.4 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'D:\Maestria\Trimestre 1\Ciencia de Datos en Python\.lab1\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
data.columns
# Out:
# Index(['SalePrice', 'OverallQual', '1stFlrSF', 'TotRmsAbvGrd', 'YearBuilt',
#        'LotFrontage'],
#       dtype='object')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

#sns.regplot(x=data.iloc[:, 0], y=data.iloc[:, 1], color='red')
for columna in data.columns:
    sns.displot(data[columna],kde=True, color='red')

# %% [markdown]
# ### 4. Para cada variable en el dataset usar seaborn(funci´on distplot https://seaborn.pydata.org/generated/seaborn.distplot.html) para graficar un histograma de la variable

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# crear figura y subplots
fig, axs = plt.subplots(nrows=5, figsize=(5,10))

for i, columna in enumerate(data.columns):
    sns.histplot(data[columna],ax=axs[i-1],color='red')

# ajustar espacios entre subplots
plt.tight_layout()

# mostrar figura
plt.show()

# %%
# !git add .
# !git commit -m "Histogramas en seaborn"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 99cc9de] Histogramas en seaborn
#  1 file changed, 242 insertions(+), 49 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    7195b3a..99cc9de  main -> main

# %% [markdown]
# ### 5. Para cada variable independiente x :

# %% [markdown]
# * Calcular el coeficiente de correlaci´on entre x y y.

# %%
{'SalePrice':
[
data['SalePrice'].corr(data['OverallQual']),
data['SalePrice'].corr(data['1stFlrSF']),
data['SalePrice'].corr(data['TotRmsAbvGrd']),
data['SalePrice'].corr(data['LotFrontage']),
data['OverallQual'].corr(data['SalePrice']),
data['SalePrice'].corr(data['OverallQual'])-data['OverallQual'].corr(data['SalePrice'])
],
'OverallQual':[
data['OverallQual'].corr(data['1stFlrSF']),
data['OverallQual'].corr(data['TotRmsAbvGrd']),
data['OverallQual'].corr(data['YearBuilt']),
data['OverallQual'].corr(data['LotFrontage'])
]
}
# Out:
# {'SalePrice': [0.7909816005838053,
#   0.6058521846919145,
#   0.5337231555820281,
#   0.351799096570678,
#   0.7909816005838052,
#   1.1102230246251565e-16],
#  'OverallQual': [0.47622382907817684,
#   0.42745234327798903,
#   0.5723227689623617,
#   0.2516457754806127]}

# %%
data
# Out:
#       SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 0      208500.0          7.0     856.0           8.0     2003.0         65.0
# 1      181500.0          6.0    1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0     920.0           6.0     2001.0         68.0
# 3      140000.0          7.0     961.0           7.0     1915.0         60.0
# 4      250000.0          8.0    1145.0           9.0     2000.0         84.0
# ...         ...          ...       ...           ...        ...          ...
# 1455   175000.0          6.0     953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0    2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0    1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0    1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0    1256.0           6.0     1965.0         75.0
#
# [1460 rows x 6 columns]

# %% [markdown]
# ####  Calcular el coeficiente de correlaci´on entre x y y

# %%
# Calcular correlación


print(data.corr())

data.corr().style.background_gradient()

data.corr().iloc[0,1]
# Out:
#               SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  \
# SalePrice      1.000000     0.790982  0.605852      0.533723   0.522897
# OverallQual    0.790982     1.000000  0.476224      0.427452   0.572323
# 1stFlrSF       0.605852     0.476224  1.000000      0.409516   0.281986
# TotRmsAbvGrd   0.533723     0.427452  0.409516      1.000000   0.095589
# YearBuilt      0.522897     0.572323  0.281986      0.095589   1.000000
# LotFrontage    0.351799     0.251646  0.457181      0.352096   0.123349
#
#               LotFrontage
# SalePrice        0.351799
# OverallQual      0.251646
# 1stFlrSF         0.457181
# TotRmsAbvGrd     0.352096
# YearBuilt        0.123349
# LotFrontage      1.000000
# 0.7909816005838053

# %%
# !git add .
# !git commit -m "Correlacion"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 56d0835] Correlacion
#  1 file changed, 510 insertions(+), 6 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    99cc9de..56d0835  main -> main

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear una matriz de gráficos de dispersión y histogramas
fig, axs = plt.subplots(len(data.columns), len(data.columns), figsize=(25, 25))

# Iterar sobre todas las combinaciones de columnas
for i in range(len(data.columns)):
    for j in range(len(data.columns)):
        # Crear un gráfico de dispersión o histograma para cada combinación de columnas

        axs[i,j].scatter(data[data.columns[j]], data[data.columns[i]],color='red')

        # Calcular la correlación y agregarla como texto en el gráfico
        corrcoef = data.corr().iloc[i,j]
        axs[i,j].text(0.05, 0.95, f"Corr: {corrcoef:.2f}", transform=axs[i,j].transAxes,ha="left", va="top")

        # Añadir etiquetas a los ejes
        if i == 0:
            axs[i,j].set_xlabel(data.columns[j])
            axs[i,j].xaxis.set_label_coords(0.5, 1.1)
        if j == 0:
            axs[i,j].set_ylabel(data.columns[i])
            
        # Ajustar los límites de los ejes
        x_min, x_max = data[data.columns[j]].min(), data[data.columns[j]].max()
        y_min, y_max = data[data.columns[i]].min(), data[data.columns[i]].max()
        x_margin, y_margin = (x_max-x_min)*0.1, (y_max-y_min)*0.1
        axs[i,j].set_xlim(x_min-x_margin, x_max+x_margin)
        axs[i,j].set_ylim(y_min-y_margin, y_max+y_margin)

plt.show()

# %% [markdown]
# * Encontre una herramienta de pandas para hacerlo directamente simplificando bastante el codigo

# %%
import pandas.plotting as pd_plot

# Crear un gráfico de dispersión para todas las columnas contra todas las demás columnas
pd_plot.scatter_matrix(data, figsize=(20, 20),color='red')

# Mostrar el gráfico
plt.show()

# %%
data.plot(color='red')
# Out:
# <AxesSubplot: >

# %%
data.columns

fig, axs = plt.subplots(len(data.columns), len(data.columns), figsize=(30, 30))

for i in range(len(data.columns)):
    for j in range(len(data.columns)): 
        axs[i,j].scatter(data.iloc[:,i], data.iloc[:,j],color='red')
        axs[i,j].xaxis.set_tick_params(labelbottom=False)
        axs[i,j].yaxis.set_tick_params(labelleft=False)
        axs[i,j].text(0.05, 0.95, f"Corr: {data.iloc[:,i].corr(data.iloc[:,j]):.2f}", transform=axs[i,j].transAxes,ha="left", va="top")
        axs[i,j].set_xlabel(data.columns[j])
        axs[i,j].set_ylabel(data.columns[i])
        #axs[i,j].set_title(data.columns[j])
        
plt.show()

# %%
# !git add .
# !git commit -m "Elegir variable con mayor correlacion"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 0675b59] Elegir variable con mayor correlacion
#  1 file changed, 516 insertions(+), 157 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    56d0835..0675b59  main -> main

# %%
#se descarta el primero ya que es la correlacion mas alta debido a que es la misma variable
data.corr()
# Out:
#               SalePrice  OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  \
# SalePrice      1.000000     0.790982  0.605852      0.533723   0.522897
# OverallQual    0.790982     1.000000  0.476224      0.427452   0.572323
# 1stFlrSF       0.605852     0.476224  1.000000      0.409516   0.281986
# TotRmsAbvGrd   0.533723     0.427452  0.409516      1.000000   0.095589
# YearBuilt      0.522897     0.572323  0.281986      0.095589   1.000000
# LotFrontage    0.351799     0.251646  0.457181      0.352096   0.123349
#
#               LotFrontage
# SalePrice        0.351799
# OverallQual      0.251646
# 1stFlrSF         0.457181
# TotRmsAbvGrd     0.352096
# YearBuilt        0.123349
# LotFrontage      1.000000

# %%
# !git add .
# !git commit -m "La mayor correlacion es de SalePrice es con la OverallQual"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 63d8c05] La mayor correlacion es de SalePrice es con la OverallQual
#  1 file changed, 168 insertions(+)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    0675b59..63d8c05  main -> main

# %% [markdown]
# ### 6. Crear una funci´on para entrenar un modelo de regresi´on lineal de una variable y = β0 +β1 ∗x.
# La funci´on recibe como argumentos:

# %%
entrenamiento = ent[['SalePrice',	'OverallQual']]

y = entrenamiento['SalePrice'].values
x = entrenamiento['OverallQual'].values

epochs = 1000
x,y


import numpy as np

def train_linear_regression_model(x, y, epochs, learning_rate = 0.000001):
  
    b0 = 0
    b1 = 0
    error_df = pd.DataFrame(columns=["Epoch", "Error"])
    for i in range(epochs):
        y_pred = b0 + b1 * x 
        error = y_pred - y

        #if i % 10 == 0:
            #print(f"Epoch {i}: Error = {np.mean(error ** 2)}")

        error_df = pd.concat([error_df, pd.DataFrame({"Epoch": [i], "Error": [np.mean(error ** 2)]})])

        b1 -= learning_rate * np.mean(error * x)
        b0 -= learning_rate * np.mean(error)
    
    # Retornar los parámetros del modelo
    return b1,b0,error_df


b1,b0,error_df=train_linear_regression_model(x, y, 200000)
print('\n',b0,' ',b1)
error_df.plot(x="Epoch", y="Error")
plt.xlabel("Epoch")
plt.ylabel("Error")
# Out:
#  3671.702815752289   29765.280183123
# Text(0, 0.5, 'Error')

# %%
error_df.plot(x="Epoch", y="Error",color='red')
plt.xlabel("Epoch")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %%
# !git add .
# !git commit -m "Color de graficas rojo y prueba de modelo primera vez"
# !git push
# Out:
# ...
# The file will have its original line endings in your working directory
# [main 09cbc9b] Color de graficas y prueba de modelo primera vez
#  1 file changed, 92 insertions(+), 544 deletions(-)
# To https://github.com/ronaldbailey/Proyecto-1---Regresi-n-con-Progra-.git
#    0ce6746..09cbc9b  main -> main
